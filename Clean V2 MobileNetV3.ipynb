# %% [markdown]
# Guide to adding layers

# %%
model = keras.models.Sequential()
model.add(layers.Conv2D(32, (3,3), strides=(1,1), padding="valid", activation='relu', input_shape=(256, 256,3)))
model.add(layers.MaxPool2D((2,2)))
model.add(layers.Conv2D(64, 3, activation='relu'))
model.add(layers.MaxPool2D((2,2)))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(5))
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model = keras.models.Sequential()
#       2 model.add(layers.Conv2D(32, (3,3), strides=(1,1), padding="valid", activation='relu', input_shape=(256, 256,3)))
#       3 model.add(layers.MaxPool2D((2,2)))
#
# NameError: name 'keras' is not defined

# %%
import os
import math
import random
import shutil

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import LeakyReLU

# %%
BASE_DIR = 'Chosen class balanced/'
names = ["Cardboard boxes","Cardboard drinks","glass","Metal cans","Metal foils and container","paper","Plastic bottles"]

tf.random.set_seed(1)

# %%
# Reorganize the folder structure:
if not os.path.isdir(BASE_DIR + 'train/'):
    for name in names:
        os.makedirs(BASE_DIR + 'train/' + name)
        os.makedirs(BASE_DIR + 'val/' + name)
        os.makedirs(BASE_DIR + 'test/' + name)

# %%
# Moce the image files
orig_folders = ["Cardboard boxes/","Cardboard drinks/","glass/","Metal cans/","Metal foils and container/","paper/","Plastic bottles/"]
for folder_idx, folder in enumerate(orig_folders):
    files = os.listdir(BASE_DIR + folder)
    number_of_images = len([name for name in files])
    n_train = int((number_of_images * 0.6) + 0.5) #set 60% for training
    n_valid = int((number_of_images*0.25) + 0.5) #set 25% for validation
    n_test = number_of_images - n_train - n_valid #set 15% for test
    print(number_of_images, n_train, n_valid, n_test)
    for idx, file in enumerate(files):
        file_name = BASE_DIR + folder + file
        if idx < n_train:
            shutil.move(file_name, BASE_DIR + "train/" + names[folder_idx])
        elif idx < n_train + n_valid:
            shutil.move(file_name, BASE_DIR + "val/" + names[folder_idx])
        else:
            shutil.move(file_name, BASE_DIR + "test/" + names[folder_idx])
# Out:
# 1938 1163 485 290
# 3737 2242 934 561
# 1986 1192 497 297
# 2092 1255 523 314
# 2302 1381 576 345
# 834 500 209 125
# 985 591 246 148

# %%
# get the preprocessing function of this model
preprocess_input = tf.keras.applications.mobilenet_v3.preprocess_input

# %%
# Generate batches of tensor image data with real-time data augmentation.

train_gen = keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocess_input)
valid_gen = keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocess_input)
test_gen = keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocess_input)

train_batches = train_gen.flow_from_directory(
    'Chosen class balanced/train',
    target_size=(224, 224),
    class_mode='sparse',
    batch_size=4,
    shuffle=True,
    color_mode="rgb",
    classes=names   
)

val_batches = valid_gen.flow_from_directory(
    'Chosen class balanced/val',
    target_size=(224, 224),
    class_mode='sparse',
    batch_size=4,
    shuffle=True,
    color_mode="rgb",
    classes=names
)

test_batches = test_gen.flow_from_directory(
    'Chosen class balanced/test',
    target_size=(224, 224),
    class_mode='sparse',
    batch_size=1,
    shuffle=False,
    color_mode="rgb",
    classes=names
)
# Out:
# Found 2100 images belonging to 7 classes.
# Found 875 images belonging to 7 classes.
# Found 525 images belonging to 7 classes.

# %%
mobileNetv1_model = tf.keras.applications.MobileNetV3Small()
print(type(mobileNetv1_model))
mobileNetv1_model.summary()

# try out different ones, e.g. MobileNetV2
#tl_model = tf.keras.applications.MobileNetV2()
#print(type(tl_model))
#tl_model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# <class 'keras.src.engine.functional.Functional'>
# Model: "MobilenetV3small"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, None, None, 3)]      0         []
#
#  rescaling_3 (Rescaling)     (None, None, None, 3)        0         ['input_4[0][0]']
#
#  Conv (Conv2D)               (None, None, None, 16)       432       ['rescaling_3[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, None, None, 16)       64        ['Conv[0][0]']
#  lization)
#
#  tf.math.add_84 (TFOpLambda  (None, None, None, 16)       0         ['Conv/BatchNorm[0][0]']
#  )
#
#  re_lu_99 (ReLU)             (None, None, None, 16)       0         ['tf.math.add_84[0][0]']
#
#  tf.math.multiply_84 (TFOpL  (None, None, None, 16)       0         ['re_lu_99[0][0]']
#  ambda)
#
#  multiply_57 (Multiply)      (None, None, None, 16)       0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_84[0][0]']
#
#  expanded_conv/depthwise/pa  (None, None, None, 16)       0         ['multiply_57[0][0]']
#  d (ZeroPadding2D)
#
#  expanded_conv/depthwise (D  (None, None, None, 16)       144       ['expanded_conv/depthwise/pad[
#  epthwiseConv2D)                                                    0][0]']
#
#  expanded_conv/depthwise/Ba  (None, None, None, 16)       64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_100 (ReLU)            (None, None, None, 16)       0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             0         ['re_lu_100[0][0]']
#  te/AvgPool (GlobalAverageP
#  ooling2D)
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              136       ['expanded_conv/squeeze_excite
#  te/Conv (Conv2D)                                                   /AvgPool[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              0         ['expanded_conv/squeeze_excite
#  te/Relu (ReLU)                                                     /Conv[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             144       ['expanded_conv/squeeze_excite
#  te/Conv_1 (Conv2D)                                                 /Relu[0][0]']
#
#  tf.math.add_85 (TFOpLambda  (None, 1, 1, 16)             0         ['expanded_conv/squeeze_excite
#  )                                                                  /Conv_1[0][0]']
#
#  re_lu_101 (ReLU)            (None, 1, 1, 16)             0         ['tf.math.add_85[0][0]']
#
#  tf.math.multiply_85 (TFOpL  (None, 1, 1, 16)             0         ['re_lu_101[0][0]']
#  ambda)
#
#  expanded_conv/squeeze_exci  (None, None, None, 16)       0         ['re_lu_100[0][0]',
#  te/Mul (Multiply)                                                   'tf.math.multiply_85[0][0]']
#
#  expanded_conv/project (Con  (None, None, None, 16)       256       ['expanded_conv/squeeze_excite
#  v2D)                                                               /Mul[0][0]']
#
#  expanded_conv/project/Batc  (None, None, None, 16)       64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv_1/expand (Co  (None, None, None, 72)       1152      ['expanded_conv/project/BatchN
#  nv2D)                                                              orm[0][0]']
#
#  expanded_conv_1/expand/Bat  (None, None, None, 72)       288       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_102 (ReLU)            (None, None, None, 72)       0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, None, None, 72)       0         ['re_lu_102[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, None, None, 72)       648       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, None, None, 72)       288       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_103 (ReLU)            (None, None, None, 72)       0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, None, None, 24)       1728      ['re_lu_103[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, None, None, 24)       96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, None, None, 88)       2112      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, None, None, 88)       352       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_104 (ReLU)            (None, None, None, 88)       0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, None, None, 88)       792       ['re_lu_104[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, None, None, 88)       352       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_105 (ReLU)            (None, None, None, 88)       0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, None, None, 24)       2112      ['re_lu_105[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, None, None, 24)       96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, None, None, 24)       0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, None, None, 96)       2304      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, None, None, 96)       384       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_86 (TFOpLambda  (None, None, None, 96)       0         ['expanded_conv_3/expand/Batch
#  )                                                                  Norm[0][0]']
#
#  re_lu_106 (ReLU)            (None, None, None, 96)       0         ['tf.math.add_86[0][0]']
#
#  tf.math.multiply_86 (TFOpL  (None, None, None, 96)       0         ['re_lu_106[0][0]']
#  ambda)
#
#  multiply_58 (Multiply)      (None, None, None, 96)       0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_86[0][0]']
#
#  expanded_conv_3/depthwise/  (None, None, None, 96)       0         ['multiply_58[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, None, None, 96)       2400      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, None, None, 96)       384       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_87 (TFOpLambda  (None, None, None, 96)       0         ['expanded_conv_3/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_107 (ReLU)            (None, None, None, 96)       0         ['tf.math.add_87[0][0]']
#
#  tf.math.multiply_87 (TFOpL  (None, None, None, 96)       0         ['re_lu_107[0][0]']
#  ambda)
#
#  multiply_59 (Multiply)      (None, None, None, 96)       0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_87[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             0         ['multiply_59[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             2328      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             2400      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_88 (TFOpLambda  (None, 1, 1, 96)             0         ['expanded_conv_3/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_108 (ReLU)            (None, 1, 1, 96)             0         ['tf.math.add_88[0][0]']
#
#  tf.math.multiply_88 (TFOpL  (None, 1, 1, 96)             0         ['re_lu_108[0][0]']
#  ambda)
#
#  expanded_conv_3/squeeze_ex  (None, None, None, 96)       0         ['multiply_59[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_88[0][0]']
#
#  expanded_conv_3/project (C  (None, None, None, 40)       3840      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, None, None, 40)       160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, None, None, 240)      9600      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, None, None, 240)      960       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_89 (TFOpLambda  (None, None, None, 240)      0         ['expanded_conv_4/expand/Batch
#  )                                                                  Norm[0][0]']
#
#  re_lu_109 (ReLU)            (None, None, None, 240)      0         ['tf.math.add_89[0][0]']
#
#  tf.math.multiply_89 (TFOpL  (None, None, None, 240)      0         ['re_lu_109[0][0]']
#  ambda)
#
#  multiply_60 (Multiply)      (None, None, None, 240)      0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_89[0][0]']
#
#  expanded_conv_4/depthwise   (None, None, None, 240)      6000      ['multiply_60[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, None, None, 240)      960       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_90 (TFOpLambda  (None, None, None, 240)      0         ['expanded_conv_4/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_110 (ReLU)            (None, None, None, 240)      0         ['tf.math.add_90[0][0]']
#
#  tf.math.multiply_90 (TFOpL  (None, None, None, 240)      0         ['re_lu_110[0][0]']
#  ambda)
#
#  multiply_61 (Multiply)      (None, None, None, 240)      0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_90[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_61[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_91 (TFOpLambda  (None, 1, 1, 240)            0         ['expanded_conv_4/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_111 (ReLU)            (None, 1, 1, 240)            0         ['tf.math.add_91[0][0]']
#
#  tf.math.multiply_91 (TFOpL  (None, 1, 1, 240)            0         ['re_lu_111[0][0]']
#  ambda)
#
#  expanded_conv_4/squeeze_ex  (None, None, None, 240)      0         ['multiply_61[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_91[0][0]']
#
#  expanded_conv_4/project (C  (None, None, None, 40)       9600      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, None, None, 40)       160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, None, None, 40)       0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, None, None, 240)      9600      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, None, None, 240)      960       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_92 (TFOpLambda  (None, None, None, 240)      0         ['expanded_conv_5/expand/Batch
#  )                                                                  Norm[0][0]']
#
#  re_lu_112 (ReLU)            (None, None, None, 240)      0         ['tf.math.add_92[0][0]']
#
#  tf.math.multiply_92 (TFOpL  (None, None, None, 240)      0         ['re_lu_112[0][0]']
#  ambda)
#
#  multiply_62 (Multiply)      (None, None, None, 240)      0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_92[0][0]']
#
#  expanded_conv_5/depthwise   (None, None, None, 240)      6000      ['multiply_62[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, None, None, 240)      960       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_93 (TFOpLambda  (None, None, None, 240)      0         ['expanded_conv_5/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_113 (ReLU)            (None, None, None, 240)      0         ['tf.math.add_93[0][0]']
#
#  tf.math.multiply_93 (TFOpL  (None, None, None, 240)      0         ['re_lu_113[0][0]']
#  ambda)
#
#  multiply_63 (Multiply)      (None, None, None, 240)      0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_93[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_63[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_94 (TFOpLambda  (None, 1, 1, 240)            0         ['expanded_conv_5/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_114 (ReLU)            (None, 1, 1, 240)            0         ['tf.math.add_94[0][0]']
#  tf.math.multiply_94 (TFOpL  (None, 1, 1, 240)            0         ['re_lu_114[0][0]']
#  ambda)
#
#  expanded_conv_5/squeeze_ex  (None, None, None, 240)      0         ['multiply_63[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_94[0][0]']
#
#  expanded_conv_5/project (C  (None, None, None, 40)       9600      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, None, None, 40)       160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, None, None, 40)       0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, None, None, 120)      4800      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, None, None, 120)      480       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_95 (TFOpLambda  (None, None, None, 120)      0         ['expanded_conv_6/expand/Batch
#  )                                                                  Norm[0][0]']
#
#  re_lu_115 (ReLU)            (None, None, None, 120)      0         ['tf.math.add_95[0][0]']
#
#  tf.math.multiply_95 (TFOpL  (None, None, None, 120)      0         ['re_lu_115[0][0]']
#  ambda)
#
#  multiply_64 (Multiply)      (None, None, None, 120)      0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_95[0][0]']
#
#  expanded_conv_6/depthwise   (None, None, None, 120)      3000      ['multiply_64[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_6/depthwise/  (None, None, None, 120)      480       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_96 (TFOpLambda  (None, None, None, 120)      0         ['expanded_conv_6/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_116 (ReLU)            (None, None, None, 120)      0         ['tf.math.add_96[0][0]']
#
#  tf.math.multiply_96 (TFOpL  (None, None, None, 120)      0         ['re_lu_116[0][0]']
#  ambda)
#
#  multiply_65 (Multiply)      (None, None, None, 120)      0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_96[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            0         ['multiply_65[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_6/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_6/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_6/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_97 (TFOpLambda  (None, 1, 1, 120)            0         ['expanded_conv_6/squeeze_exci
#  )                                                                  te/Conv_1[0][0]']
#
#  re_lu_117 (ReLU)            (None, 1, 1, 120)            0         ['tf.math.add_97[0][0]']
#
#  tf.math.multiply_97 (TFOpL  (None, 1, 1, 120)            0         ['re_lu_117[0][0]']
#  ambda)
#
#  expanded_conv_6/squeeze_ex  (None, None, None, 120)      0         ['multiply_65[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_97[0][0]']
#
#  expanded_conv_6/project (C  (None, None, None, 48)       5760      ['expanded_conv_6/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_6/project/Ba  (None, None, None, 48)       192       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, None, None, 144)      6912      ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, None, None, 144)      576       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_98 (TFOpLambda  (None, None, None, 144)      0         ['expanded_conv_7/expand/Batch
#  )                                                                  Norm[0][0]']
#
#  re_lu_118 (ReLU)            (None, None, None, 144)      0         ['tf.math.add_98[0][0]']
#
#  tf.math.multiply_98 (TFOpL  (None, None, None, 144)      0         ['re_lu_118[0][0]']
#  ambda)
#
#  multiply_66 (Multiply)      (None, None, None, 144)      0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_98[0][0]']
#
#  expanded_conv_7/depthwise   (None, None, None, 144)      3600      ['multiply_66[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, None, None, 144)      576       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_99 (TFOpLambda  (None, None, None, 144)      0         ['expanded_conv_7/depthwise/Ba
#  )                                                                  tchNorm[0][0]']
#
#  re_lu_119 (ReLU)            (None, None, None, 144)      0         ['tf.math.add_99[0][0]']
#
#  tf.math.multiply_99 (TFOpL  (None, None, None, 144)      0         ['re_lu_119[0][0]']
#  ambda)
#
#  multiply_67 (Multiply)      (None, None, None, 144)      0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_99[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            0         ['multiply_67[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             5800      ['expanded_conv_7/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             0         ['expanded_conv_7/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            5904      ['expanded_conv_7/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_100 (TFOpLambd  (None, 1, 1, 144)            0         ['expanded_conv_7/squeeze_exci
#  a)                                                                 te/Conv_1[0][0]']
#
#  re_lu_120 (ReLU)            (None, 1, 1, 144)            0         ['tf.math.add_100[0][0]']
#
#  tf.math.multiply_100 (TFOp  (None, 1, 1, 144)            0         ['re_lu_120[0][0]']
#  Lambda)
#
#  expanded_conv_7/squeeze_ex  (None, None, None, 144)      0         ['multiply_67[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_100[0][0]']
#
#  expanded_conv_7/project (C  (None, None, None, 48)       6912      ['expanded_conv_7/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_7/project/Ba  (None, None, None, 48)       192       ['expanded_conv_7/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
# ...
#
#  re_lu_125 (ReLU)            (None, None, None, 576)      0         ['tf.math.add_105[0][0]']
#
#  tf.math.multiply_105 (TFOp  (None, None, None, 576)      0         ['re_lu_125[0][0]']
#  Lambda)
#
#  multiply_71 (Multiply)      (None, None, None, 576)      0         ['expanded_conv_9/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_105[0][0]']
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 576)            0         ['multiply_71[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 144)            83088     ['expanded_conv_9/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 144)            0         ['expanded_conv_9/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 576)            83520     ['expanded_conv_9/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_106 (TFOpLambd  (None, 1, 1, 576)            0         ['expanded_conv_9/squeeze_exci
#  a)                                                                 te/Conv_1[0][0]']
#
#  re_lu_126 (ReLU)            (None, 1, 1, 576)            0         ['tf.math.add_106[0][0]']
#
#  tf.math.multiply_106 (TFOp  (None, 1, 1, 576)            0         ['re_lu_126[0][0]']
#  Lambda)
#
#  expanded_conv_9/squeeze_ex  (None, None, None, 576)      0         ['multiply_71[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_106[0][0]']
#
#  expanded_conv_9/project (C  (None, None, None, 96)       55296     ['expanded_conv_9/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_9/project/Ba  (None, None, None, 96)       384       ['expanded_conv_9/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_9/Add (Add)   (None, None, None, 96)       0         ['expanded_conv_8/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_9/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_10/expand (C  (None, None, None, 576)      55296     ['expanded_conv_9/Add[0][0]']
#  onv2D)
#
#  expanded_conv_10/expand/Ba  (None, None, None, 576)      2304      ['expanded_conv_10/expand[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  tf.math.add_107 (TFOpLambd  (None, None, None, 576)      0         ['expanded_conv_10/expand/Batc
#  a)                                                                 hNorm[0][0]']
#
#  re_lu_127 (ReLU)            (None, None, None, 576)      0         ['tf.math.add_107[0][0]']
#
#  tf.math.multiply_107 (TFOp  (None, None, None, 576)      0         ['re_lu_127[0][0]']
#  Lambda)
#
#  multiply_72 (Multiply)      (None, None, None, 576)      0         ['expanded_conv_10/expand/Batc
#                                                                     hNorm[0][0]',
#                                                                      'tf.math.multiply_107[0][0]']
#
#  expanded_conv_10/depthwise  (None, None, None, 576)      14400     ['multiply_72[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_10/depthwise  (None, None, None, 576)      2304      ['expanded_conv_10/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#  tf.math.add_108 (TFOpLambd  (None, None, None, 576)      0         ['expanded_conv_10/depthwise/B
#  a)                                                                 atchNorm[0][0]']
#
#  re_lu_128 (ReLU)            (None, None, None, 576)      0         ['tf.math.add_108[0][0]']
#
#  tf.math.multiply_108 (TFOp  (None, None, None, 576)      0         ['re_lu_128[0][0]']
#  Lambda)
#
#  multiply_73 (Multiply)      (None, None, None, 576)      0         ['expanded_conv_10/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_108[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            0         ['multiply_73[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            83088     ['expanded_conv_10/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            0         ['expanded_conv_10/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            83520     ['expanded_conv_10/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.math.add_109 (TFOpLambd  (None, 1, 1, 576)            0         ['expanded_conv_10/squeeze_exc
#  a)                                                                 ite/Conv_1[0][0]']
#
#  re_lu_129 (ReLU)            (None, 1, 1, 576)            0         ['tf.math.add_109[0][0]']
#
#  tf.math.multiply_109 (TFOp  (None, 1, 1, 576)            0         ['re_lu_129[0][0]']
#  Lambda)
#
#  expanded_conv_10/squeeze_e  (None, None, None, 576)      0         ['multiply_73[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_109[0][0]']
#
#  expanded_conv_10/project (  (None, None, None, 96)       55296     ['expanded_conv_10/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_10/project/B  (None, None, None, 96)       384       ['expanded_conv_10/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_10/Add (Add)  (None, None, None, 96)       0         ['expanded_conv_9/Add[0][0]',
#                                                                      'expanded_conv_10/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, None, None, 576)      55296     ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, None, None, 576)      2304      ['Conv_1[0][0]']
#  malization)
#
#  tf.math.add_110 (TFOpLambd  (None, None, None, 576)      0         ['Conv_1/BatchNorm[0][0]']
#  a)
#
#  re_lu_130 (ReLU)            (None, None, None, 576)      0         ['tf.math.add_110[0][0]']
#
#  tf.math.multiply_110 (TFOp  (None, None, None, 576)      0         ['re_lu_130[0][0]']
#  Lambda)
#
#  multiply_74 (Multiply)      (None, None, None, 576)      0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_110[0][0]']
#
#  global_average_pooling2d_3  (None, 1, 1, 576)            0         ['multiply_74[0][0]']
#   (GlobalAveragePooling2D)
#
#  Conv_2 (Conv2D)             (None, 1, 1, 1024)           590848    ['global_average_pooling2d_3[0
#                                                                     ][0]']
#
#  tf.math.add_111 (TFOpLambd  (None, 1, 1, 1024)           0         ['Conv_2[0][0]']
#  a)
#
#  re_lu_131 (ReLU)            (None, 1, 1, 1024)           0         ['tf.math.add_111[0][0]']
#
#  tf.math.multiply_111 (TFOp  (None, 1, 1, 1024)           0         ['re_lu_131[0][0]']
#  Lambda)
#
#  multiply_75 (Multiply)      (None, 1, 1, 1024)           0         ['Conv_2[0][0]',
#                                                                      'tf.math.multiply_111[0][0]']
#
#  dropout_3 (Dropout)         (None, 1, 1, 1024)           0         ['multiply_75[0][0]']
#
#  Logits (Conv2D)             (None, 1, 1, 1000)           1025000   ['dropout_3[0][0]']
#
#  flatten_3 (Flatten)         (None, 1000)                 0         ['Logits[0][0]']
#
#  Predictions (Activation)    (None, 1000)                 0         ['flatten_3[0][0]']
#
# ==================================================================================================
# Total params: 2554968 (9.75 MB)
# Trainable params: 2542856 (9.70 MB)
# Non-trainable params: 12112 (47.31 KB)
# __________________________________________________________________________________________________

# %%
#functionl API
#for nonlinear netwroks
base_model = tf.keras.applications.MobileNetV3Small()
x = base_model.layers[-1].output
x=layers.Dense(64,activation='relu')(x)
x=layers.Dense(30,activation='relu')(x)
x=layers.Dense(30,activation='relu')(x)
new_outputs = keras.layers.Dense(7)(x)

new_model = keras.Model(inputs=base_model.inputs, outputs=new_outputs)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.

# %%
new_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, None, None, 3)]      0         []
#
#  rescaling_4 (Rescaling)     (None, None, None, 3)        0         ['input_5[0][0]']
#
#  Conv (Conv2D)               (None, None, None, 16)       432       ['rescaling_4[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, None, None, 16)       64        ['Conv[0][0]']
#  lization)
#
#  tf.math.add_112 (TFOpLambd  (None, None, None, 16)       0         ['Conv/BatchNorm[0][0]']
#  a)
#
#  re_lu_132 (ReLU)            (None, None, None, 16)       0         ['tf.math.add_112[0][0]']
#
#  tf.math.multiply_112 (TFOp  (None, None, None, 16)       0         ['re_lu_132[0][0]']
#  Lambda)
#
#  multiply_76 (Multiply)      (None, None, None, 16)       0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_112[0][0]']
#
#  expanded_conv/depthwise/pa  (None, None, None, 16)       0         ['multiply_76[0][0]']
#  d (ZeroPadding2D)
#
#  expanded_conv/depthwise (D  (None, None, None, 16)       144       ['expanded_conv/depthwise/pad[
#  epthwiseConv2D)                                                    0][0]']
#
#  expanded_conv/depthwise/Ba  (None, None, None, 16)       64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_133 (ReLU)            (None, None, None, 16)       0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             0         ['re_lu_133[0][0]']
#  te/AvgPool (GlobalAverageP
#  ooling2D)
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              136       ['expanded_conv/squeeze_excite
#  te/Conv (Conv2D)                                                   /AvgPool[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              0         ['expanded_conv/squeeze_excite
#  te/Relu (ReLU)                                                     /Conv[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             144       ['expanded_conv/squeeze_excite
#  te/Conv_1 (Conv2D)                                                 /Relu[0][0]']
#
#  tf.math.add_113 (TFOpLambd  (None, 1, 1, 16)             0         ['expanded_conv/squeeze_excite
#  a)                                                                 /Conv_1[0][0]']
#
#  re_lu_134 (ReLU)            (None, 1, 1, 16)             0         ['tf.math.add_113[0][0]']
#
#  tf.math.multiply_113 (TFOp  (None, 1, 1, 16)             0         ['re_lu_134[0][0]']
#  Lambda)
#
#  expanded_conv/squeeze_exci  (None, None, None, 16)       0         ['re_lu_133[0][0]',
#  te/Mul (Multiply)                                                   'tf.math.multiply_113[0][0]']
#
#  expanded_conv/project (Con  (None, None, None, 16)       256       ['expanded_conv/squeeze_excite
#  v2D)                                                               /Mul[0][0]']
#
#  expanded_conv/project/Batc  (None, None, None, 16)       64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv_1/expand (Co  (None, None, None, 72)       1152      ['expanded_conv/project/BatchN
#  nv2D)                                                              orm[0][0]']
#
#  expanded_conv_1/expand/Bat  (None, None, None, 72)       288       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_135 (ReLU)            (None, None, None, 72)       0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, None, None, 72)       0         ['re_lu_135[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, None, None, 72)       648       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, None, None, 72)       288       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_136 (ReLU)            (None, None, None, 72)       0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, None, None, 24)       1728      ['re_lu_136[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, None, None, 24)       96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, None, None, 88)       2112      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, None, None, 88)       352       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_137 (ReLU)            (None, None, None, 88)       0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, None, None, 88)       792       ['re_lu_137[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, None, None, 88)       352       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_138 (ReLU)            (None, None, None, 88)       0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, None, None, 24)       2112      ['re_lu_138[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, None, None, 24)       96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, None, None, 24)       0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, None, None, 96)       2304      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, None, None, 96)       384       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_114 (TFOpLambd  (None, None, None, 96)       0         ['expanded_conv_3/expand/Batch
#  a)                                                                 Norm[0][0]']
#
#  re_lu_139 (ReLU)            (None, None, None, 96)       0         ['tf.math.add_114[0][0]']
#
#  tf.math.multiply_114 (TFOp  (None, None, None, 96)       0         ['re_lu_139[0][0]']
#  Lambda)
#
#  multiply_77 (Multiply)      (None, None, None, 96)       0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_114[0][0]']
#
#  expanded_conv_3/depthwise/  (None, None, None, 96)       0         ['multiply_77[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, None, None, 96)       2400      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, None, None, 96)       384       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_115 (TFOpLambd  (None, None, None, 96)       0         ['expanded_conv_3/depthwise/Ba
#  a)                                                                 tchNorm[0][0]']
#
#  re_lu_140 (ReLU)            (None, None, None, 96)       0         ['tf.math.add_115[0][0]']
#
#  tf.math.multiply_115 (TFOp  (None, None, None, 96)       0         ['re_lu_140[0][0]']
#  Lambda)
#
#  multiply_78 (Multiply)      (None, None, None, 96)       0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_115[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             0         ['multiply_78[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             2328      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             2400      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_116 (TFOpLambd  (None, 1, 1, 96)             0         ['expanded_conv_3/squeeze_exci
#  a)                                                                 te/Conv_1[0][0]']
#
#  re_lu_141 (ReLU)            (None, 1, 1, 96)             0         ['tf.math.add_116[0][0]']
#
#  tf.math.multiply_116 (TFOp  (None, 1, 1, 96)             0         ['re_lu_141[0][0]']
#  Lambda)
#
#  expanded_conv_3/squeeze_ex  (None, None, None, 96)       0         ['multiply_78[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_116[0][0]']
#
#  expanded_conv_3/project (C  (None, None, None, 40)       3840      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, None, None, 40)       160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, None, None, 240)      9600      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, None, None, 240)      960       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_117 (TFOpLambd  (None, None, None, 240)      0         ['expanded_conv_4/expand/Batch
#  a)                                                                 Norm[0][0]']
#
#  re_lu_142 (ReLU)            (None, None, None, 240)      0         ['tf.math.add_117[0][0]']
#
#  tf.math.multiply_117 (TFOp  (None, None, None, 240)      0         ['re_lu_142[0][0]']
#  Lambda)
#
#  multiply_79 (Multiply)      (None, None, None, 240)      0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_117[0][0]']
#
#  expanded_conv_4/depthwise   (None, None, None, 240)      6000      ['multiply_79[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, None, None, 240)      960       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_118 (TFOpLambd  (None, None, None, 240)      0         ['expanded_conv_4/depthwise/Ba
#  a)                                                                 tchNorm[0][0]']
#
#  re_lu_143 (ReLU)            (None, None, None, 240)      0         ['tf.math.add_118[0][0]']
#
#  tf.math.multiply_118 (TFOp  (None, None, None, 240)      0         ['re_lu_143[0][0]']
#  Lambda)
#
#  multiply_80 (Multiply)      (None, None, None, 240)      0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_118[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_80[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_119 (TFOpLambd  (None, 1, 1, 240)            0         ['expanded_conv_4/squeeze_exci
#  a)                                                                 te/Conv_1[0][0]']
#
#  re_lu_144 (ReLU)            (None, 1, 1, 240)            0         ['tf.math.add_119[0][0]']
#
#  tf.math.multiply_119 (TFOp  (None, 1, 1, 240)            0         ['re_lu_144[0][0]']
#  Lambda)
#
#  expanded_conv_4/squeeze_ex  (None, None, None, 240)      0         ['multiply_80[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_119[0][0]']
#
#  expanded_conv_4/project (C  (None, None, None, 40)       9600      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, None, None, 40)       160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, None, None, 40)       0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, None, None, 240)      9600      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, None, None, 240)      960       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_120 (TFOpLambd  (None, None, None, 240)      0         ['expanded_conv_5/expand/Batch
#  a)                                                                 Norm[0][0]']
#
#  re_lu_145 (ReLU)            (None, None, None, 240)      0         ['tf.math.add_120[0][0]']
#
#  tf.math.multiply_120 (TFOp  (None, None, None, 240)      0         ['re_lu_145[0][0]']
#  Lambda)
#
#  multiply_81 (Multiply)      (None, None, None, 240)      0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_120[0][0]']
#
#  expanded_conv_5/depthwise   (None, None, None, 240)      6000      ['multiply_81[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, None, None, 240)      960       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_121 (TFOpLambd  (None, None, None, 240)      0         ['expanded_conv_5/depthwise/Ba
#  a)                                                                 tchNorm[0][0]']
#
#  re_lu_146 (ReLU)            (None, None, None, 240)      0         ['tf.math.add_121[0][0]']
#
#  tf.math.multiply_121 (TFOp  (None, None, None, 240)      0         ['re_lu_146[0][0]']
#  Lambda)
#
#  multiply_82 (Multiply)      (None, None, None, 240)      0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_121[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_82[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_122 (TFOpLambd  (None, 1, 1, 240)            0         ['expanded_conv_5/squeeze_exci
#  a)                                                                 te/Conv_1[0][0]']
#
#  re_lu_147 (ReLU)            (None, 1, 1, 240)            0         ['tf.math.add_122[0][0]']
#
#  tf.math.multiply_122 (TFOp  (None, 1, 1, 240)            0         ['re_lu_147[0][0]']
#  Lambda)
#
#  expanded_conv_5/squeeze_ex  (None, None, None, 240)      0         ['multiply_82[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_122[0][0]']
#
#  expanded_conv_5/project (C  (None, None, None, 40)       9600      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, None, None, 40)       160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, None, None, 40)       0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, None, None, 120)      4800      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, None, None, 120)      480       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_123 (TFOpLambd  (None, None, None, 120)      0         ['expanded_conv_6/expand/Batch
#  a)                                                                 Norm[0][0]']
#
#  re_lu_148 (ReLU)            (None, None, None, 120)      0         ['tf.math.add_123[0][0]']
#
#  tf.math.multiply_123 (TFOp  (None, None, None, 120)      0         ['re_lu_148[0][0]']
#  Lambda)
#
#  multiply_83 (Multiply)      (None, None, None, 120)      0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_123[0][0]']
#
#  expanded_conv_6/depthwise   (None, None, None, 120)      3000      ['multiply_83[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_6/depthwise/  (None, None, None, 120)      480       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_124 (TFOpLambd  (None, None, None, 120)      0         ['expanded_conv_6/depthwise/Ba
#  a)                                                                 tchNorm[0][0]']
#
#  re_lu_149 (ReLU)            (None, None, None, 120)      0         ['tf.math.add_124[0][0]']
#
#  tf.math.multiply_124 (TFOp  (None, None, None, 120)      0         ['re_lu_149[0][0]']
#  Lambda)
#
#  multiply_84 (Multiply)      (None, None, None, 120)      0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_124[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            0         ['multiply_84[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_6/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_6/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_6/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_125 (TFOpLambd  (None, 1, 1, 120)            0         ['expanded_conv_6/squeeze_exci
#  a)                                                                 te/Conv_1[0][0]']
#
#  re_lu_150 (ReLU)            (None, 1, 1, 120)            0         ['tf.math.add_125[0][0]']
#
#  tf.math.multiply_125 (TFOp  (None, 1, 1, 120)            0         ['re_lu_150[0][0]']
#  Lambda)
#
#  expanded_conv_6/squeeze_ex  (None, None, None, 120)      0         ['multiply_84[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_125[0][0]']
#
#  expanded_conv_6/project (C  (None, None, None, 48)       5760      ['expanded_conv_6/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_6/project/Ba  (None, None, None, 48)       192       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, None, None, 144)      6912      ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, None, None, 144)      576       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_126 (TFOpLambd  (None, None, None, 144)      0         ['expanded_conv_7/expand/Batch
#  a)                                                                 Norm[0][0]']
#
#  re_lu_151 (ReLU)            (None, None, None, 144)      0         ['tf.math.add_126[0][0]']
#
#  tf.math.multiply_126 (TFOp  (None, None, None, 144)      0         ['re_lu_151[0][0]']
#  Lambda)
#
#  multiply_85 (Multiply)      (None, None, None, 144)      0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_126[0][0]']
#
#  expanded_conv_7/depthwise   (None, None, None, 144)      3600      ['multiply_85[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, None, None, 144)      576       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_127 (TFOpLambd  (None, None, None, 144)      0         ['expanded_conv_7/depthwise/Ba
#  a)                                                                 tchNorm[0][0]']
#
#  re_lu_152 (ReLU)            (None, None, None, 144)      0         ['tf.math.add_127[0][0]']
#
#  tf.math.multiply_127 (TFOp  (None, None, None, 144)      0         ['re_lu_152[0][0]']
#  Lambda)
#
#  multiply_86 (Multiply)      (None, None, None, 144)      0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_127[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            0         ['multiply_86[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             5800      ['expanded_conv_7/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             0         ['expanded_conv_7/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            5904      ['expanded_conv_7/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_128 (TFOpLambd  (None, 1, 1, 144)            0         ['expanded_conv_7/squeeze_exci
#  a)                                                                 te/Conv_1[0][0]']
#
#  re_lu_153 (ReLU)            (None, 1, 1, 144)            0         ['tf.math.add_128[0][0]']
#
#  tf.math.multiply_128 (TFOp  (None, 1, 1, 144)            0         ['re_lu_153[0][0]']
#  Lambda)
#
#  expanded_conv_7/squeeze_ex  (None, None, None, 144)      0         ['multiply_86[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_128[0][0]']
#
#  expanded_conv_7/project (C  (None, None, None, 48)       6912      ['expanded_conv_7/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_7/project/Ba  (None, None, None, 48)       192       ['expanded_conv_7/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/Add (Add)   (None, None, None, 48)       0         ['expanded_conv_6/project/Batc
# ...
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 576)            0         ['multiply_90[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 144)            83088     ['expanded_conv_9/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 144)            0         ['expanded_conv_9/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 576)            83520     ['expanded_conv_9/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_134 (TFOpLambd  (None, 1, 1, 576)            0         ['expanded_conv_9/squeeze_exci
#  a)                                                                 te/Conv_1[0][0]']
#
#  re_lu_159 (ReLU)            (None, 1, 1, 576)            0         ['tf.math.add_134[0][0]']
#
#  tf.math.multiply_134 (TFOp  (None, 1, 1, 576)            0         ['re_lu_159[0][0]']
#  Lambda)
#
#  expanded_conv_9/squeeze_ex  (None, None, None, 576)      0         ['multiply_90[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_134[0][0]']
#
#  expanded_conv_9/project (C  (None, None, None, 96)       55296     ['expanded_conv_9/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_9/project/Ba  (None, None, None, 96)       384       ['expanded_conv_9/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_9/Add (Add)   (None, None, None, 96)       0         ['expanded_conv_8/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_9/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_10/expand (C  (None, None, None, 576)      55296     ['expanded_conv_9/Add[0][0]']
#  onv2D)
#
#  expanded_conv_10/expand/Ba  (None, None, None, 576)      2304      ['expanded_conv_10/expand[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  tf.math.add_135 (TFOpLambd  (None, None, None, 576)      0         ['expanded_conv_10/expand/Batc
#  a)                                                                 hNorm[0][0]']
#
#  re_lu_160 (ReLU)            (None, None, None, 576)      0         ['tf.math.add_135[0][0]']
#
#  tf.math.multiply_135 (TFOp  (None, None, None, 576)      0         ['re_lu_160[0][0]']
#  Lambda)
#
#  multiply_91 (Multiply)      (None, None, None, 576)      0         ['expanded_conv_10/expand/Batc
#                                                                     hNorm[0][0]',
#                                                                      'tf.math.multiply_135[0][0]']
#
#  expanded_conv_10/depthwise  (None, None, None, 576)      14400     ['multiply_91[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_10/depthwise  (None, None, None, 576)      2304      ['expanded_conv_10/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.math.add_136 (TFOpLambd  (None, None, None, 576)      0         ['expanded_conv_10/depthwise/B
#  a)                                                                 atchNorm[0][0]']
#
#  re_lu_161 (ReLU)            (None, None, None, 576)      0         ['tf.math.add_136[0][0]']
#
#  tf.math.multiply_136 (TFOp  (None, None, None, 576)      0         ['re_lu_161[0][0]']
#  Lambda)
#
#  multiply_92 (Multiply)      (None, None, None, 576)      0         ['expanded_conv_10/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_136[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            0         ['multiply_92[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            83088     ['expanded_conv_10/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            0         ['expanded_conv_10/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            83520     ['expanded_conv_10/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.math.add_137 (TFOpLambd  (None, 1, 1, 576)            0         ['expanded_conv_10/squeeze_exc
#  a)                                                                 ite/Conv_1[0][0]']
#
#  re_lu_162 (ReLU)            (None, 1, 1, 576)            0         ['tf.math.add_137[0][0]']
#
#  tf.math.multiply_137 (TFOp  (None, 1, 1, 576)            0         ['re_lu_162[0][0]']
#  Lambda)
#
#  expanded_conv_10/squeeze_e  (None, None, None, 576)      0         ['multiply_92[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_137[0][0]']
#
#  expanded_conv_10/project (  (None, None, None, 96)       55296     ['expanded_conv_10/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_10/project/B  (None, None, None, 96)       384       ['expanded_conv_10/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_10/Add (Add)  (None, None, None, 96)       0         ['expanded_conv_9/Add[0][0]',
#                                                                      'expanded_conv_10/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, None, None, 576)      55296     ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, None, None, 576)      2304      ['Conv_1[0][0]']
#  malization)
#
#  tf.math.add_138 (TFOpLambd  (None, None, None, 576)      0         ['Conv_1/BatchNorm[0][0]']
#  a)
#
#  re_lu_163 (ReLU)            (None, None, None, 576)      0         ['tf.math.add_138[0][0]']
#
#  tf.math.multiply_138 (TFOp  (None, None, None, 576)      0         ['re_lu_163[0][0]']
#  Lambda)
#
#  multiply_93 (Multiply)      (None, None, None, 576)      0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_138[0][0]']
#
#  global_average_pooling2d_4  (None, 1, 1, 576)            0         ['multiply_93[0][0]']
#   (GlobalAveragePooling2D)
#
#  Conv_2 (Conv2D)             (None, 1, 1, 1024)           590848    ['global_average_pooling2d_4[0
#                                                                     ][0]']
#
#  tf.math.add_139 (TFOpLambd  (None, 1, 1, 1024)           0         ['Conv_2[0][0]']
#  a)
#
#  re_lu_164 (ReLU)            (None, 1, 1, 1024)           0         ['tf.math.add_139[0][0]']
#
#  tf.math.multiply_139 (TFOp  (None, 1, 1, 1024)           0         ['re_lu_164[0][0]']
#  Lambda)
#
#  multiply_94 (Multiply)      (None, 1, 1, 1024)           0         ['Conv_2[0][0]',
#                                                                      'tf.math.multiply_139[0][0]']
#
#  dropout_4 (Dropout)         (None, 1, 1, 1024)           0         ['multiply_94[0][0]']
#
#  Logits (Conv2D)             (None, 1, 1, 1000)           1025000   ['dropout_4[0][0]']
#
#  flatten_4 (Flatten)         (None, 1000)                 0         ['Logits[0][0]']
#
#  Predictions (Activation)    (None, 1000)                 0         ['flatten_4[0][0]']
#
#  dense_4 (Dense)             (None, 64)                   64064     ['Predictions[0][0]']
#
#  dense_5 (Dense)             (None, 30)                   1950      ['dense_4[0][0]']
#
#  dense_6 (Dense)             (None, 30)                   930       ['dense_5[0][0]']
#
#  dense_7 (Dense)             (None, 7)                    217       ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 2622129 (10.00 MB)
# Trainable params: 2610017 (9.96 MB)
# Non-trainable params: 12112 (47.31 KB)
# __________________________________________________________________________________________________

# %%
# set trainable=False for all layers
# we don't want to train them again
for layer in new_model.layers:
    layer.trainable = False
new_model.layers[-1].trainable=True
new_model.layers[-2].trainable=True
new_model.layers[-3].trainable=True
new_model.layers[-4].trainable=True
new_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, None, None, 3)]      0         []
#
#  rescaling_4 (Rescaling)     (None, None, None, 3)        0         ['input_5[0][0]']
#
#  Conv (Conv2D)               (None, None, None, 16)       432       ['rescaling_4[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, None, None, 16)       64        ['Conv[0][0]']
#  lization)
#
#  tf.math.add_112 (TFOpLambd  (None, None, None, 16)       0         ['Conv/BatchNorm[0][0]']
#  a)
#
#  re_lu_132 (ReLU)            (None, None, None, 16)       0         ['tf.math.add_112[0][0]']
#
#  tf.math.multiply_112 (TFOp  (None, None, None, 16)       0         ['re_lu_132[0][0]']
#  Lambda)
#
#  multiply_76 (Multiply)      (None, None, None, 16)       0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_112[0][0]']
#
#  expanded_conv/depthwise/pa  (None, None, None, 16)       0         ['multiply_76[0][0]']
#  d (ZeroPadding2D)
#
#  expanded_conv/depthwise (D  (None, None, None, 16)       144       ['expanded_conv/depthwise/pad[
#  epthwiseConv2D)                                                    0][0]']
#
#  expanded_conv/depthwise/Ba  (None, None, None, 16)       64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_133 (ReLU)            (None, None, None, 16)       0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             0         ['re_lu_133[0][0]']
#  te/AvgPool (GlobalAverageP
#  ooling2D)
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              136       ['expanded_conv/squeeze_excite
#  te/Conv (Conv2D)                                                   /AvgPool[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 8)              0         ['expanded_conv/squeeze_excite
#  te/Relu (ReLU)                                                     /Conv[0][0]']
#
#  expanded_conv/squeeze_exci  (None, 1, 1, 16)             144       ['expanded_conv/squeeze_excite
#  te/Conv_1 (Conv2D)                                                 /Relu[0][0]']
#
#  tf.math.add_113 (TFOpLambd  (None, 1, 1, 16)             0         ['expanded_conv/squeeze_excite
#  a)                                                                 /Conv_1[0][0]']
#
#  re_lu_134 (ReLU)            (None, 1, 1, 16)             0         ['tf.math.add_113[0][0]']
#
#  tf.math.multiply_113 (TFOp  (None, 1, 1, 16)             0         ['re_lu_134[0][0]']
#  Lambda)
#
#  expanded_conv/squeeze_exci  (None, None, None, 16)       0         ['re_lu_133[0][0]',
#  te/Mul (Multiply)                                                   'tf.math.multiply_113[0][0]']
#
#  expanded_conv/project (Con  (None, None, None, 16)       256       ['expanded_conv/squeeze_excite
#  v2D)                                                               /Mul[0][0]']
#
#  expanded_conv/project/Batc  (None, None, None, 16)       64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv_1/expand (Co  (None, None, None, 72)       1152      ['expanded_conv/project/BatchN
#  nv2D)                                                              orm[0][0]']
#
#  expanded_conv_1/expand/Bat  (None, None, None, 72)       288       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_135 (ReLU)            (None, None, None, 72)       0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, None, None, 72)       0         ['re_lu_135[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, None, None, 72)       648       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, None, None, 72)       288       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_136 (ReLU)            (None, None, None, 72)       0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, None, None, 24)       1728      ['re_lu_136[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, None, None, 24)       96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, None, None, 88)       2112      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, None, None, 88)       352       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_137 (ReLU)            (None, None, None, 88)       0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, None, None, 88)       792       ['re_lu_137[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, None, None, 88)       352       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_138 (ReLU)            (None, None, None, 88)       0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, None, None, 24)       2112      ['re_lu_138[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, None, None, 24)       96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, None, None, 24)       0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, None, None, 96)       2304      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, None, None, 96)       384       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_114 (TFOpLambd  (None, None, None, 96)       0         ['expanded_conv_3/expand/Batch
#  a)                                                                 Norm[0][0]']
#
#  re_lu_139 (ReLU)            (None, None, None, 96)       0         ['tf.math.add_114[0][0]']
#
#  tf.math.multiply_114 (TFOp  (None, None, None, 96)       0         ['re_lu_139[0][0]']
#  Lambda)
#
#  multiply_77 (Multiply)      (None, None, None, 96)       0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_114[0][0]']
#
#  expanded_conv_3/depthwise/  (None, None, None, 96)       0         ['multiply_77[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, None, None, 96)       2400      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, None, None, 96)       384       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_115 (TFOpLambd  (None, None, None, 96)       0         ['expanded_conv_3/depthwise/Ba
#  a)                                                                 tchNorm[0][0]']
#
#  re_lu_140 (ReLU)            (None, None, None, 96)       0         ['tf.math.add_115[0][0]']
#
#  tf.math.multiply_115 (TFOp  (None, None, None, 96)       0         ['re_lu_140[0][0]']
#  Lambda)
#
#  multiply_78 (Multiply)      (None, None, None, 96)       0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_115[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             0         ['multiply_78[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             2328      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 96)             2400      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_116 (TFOpLambd  (None, 1, 1, 96)             0         ['expanded_conv_3/squeeze_exci
#  a)                                                                 te/Conv_1[0][0]']
#
#  re_lu_141 (ReLU)            (None, 1, 1, 96)             0         ['tf.math.add_116[0][0]']
#
#  tf.math.multiply_116 (TFOp  (None, 1, 1, 96)             0         ['re_lu_141[0][0]']
#  Lambda)
#
#  expanded_conv_3/squeeze_ex  (None, None, None, 96)       0         ['multiply_78[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_116[0][0]']
#
#  expanded_conv_3/project (C  (None, None, None, 40)       3840      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, None, None, 40)       160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, None, None, 240)      9600      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, None, None, 240)      960       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_117 (TFOpLambd  (None, None, None, 240)      0         ['expanded_conv_4/expand/Batch
#  a)                                                                 Norm[0][0]']
#
#  re_lu_142 (ReLU)            (None, None, None, 240)      0         ['tf.math.add_117[0][0]']
#
#  tf.math.multiply_117 (TFOp  (None, None, None, 240)      0         ['re_lu_142[0][0]']
#  Lambda)
#
#  multiply_79 (Multiply)      (None, None, None, 240)      0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_117[0][0]']
#
#  expanded_conv_4/depthwise   (None, None, None, 240)      6000      ['multiply_79[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, None, None, 240)      960       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_118 (TFOpLambd  (None, None, None, 240)      0         ['expanded_conv_4/depthwise/Ba
#  a)                                                                 tchNorm[0][0]']
#
#  re_lu_143 (ReLU)            (None, None, None, 240)      0         ['tf.math.add_118[0][0]']
#
#  tf.math.multiply_118 (TFOp  (None, None, None, 240)      0         ['re_lu_143[0][0]']
#  Lambda)
#
#  multiply_80 (Multiply)      (None, None, None, 240)      0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_118[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_80[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_119 (TFOpLambd  (None, 1, 1, 240)            0         ['expanded_conv_4/squeeze_exci
#  a)                                                                 te/Conv_1[0][0]']
#
#  re_lu_144 (ReLU)            (None, 1, 1, 240)            0         ['tf.math.add_119[0][0]']
#
#  tf.math.multiply_119 (TFOp  (None, 1, 1, 240)            0         ['re_lu_144[0][0]']
#  Lambda)
#
#  expanded_conv_4/squeeze_ex  (None, None, None, 240)      0         ['multiply_80[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_119[0][0]']
#
#  expanded_conv_4/project (C  (None, None, None, 40)       9600      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, None, None, 40)       160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, None, None, 40)       0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, None, None, 240)      9600      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, None, None, 240)      960       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_120 (TFOpLambd  (None, None, None, 240)      0         ['expanded_conv_5/expand/Batch
#  a)                                                                 Norm[0][0]']
#
#  re_lu_145 (ReLU)            (None, None, None, 240)      0         ['tf.math.add_120[0][0]']
#
#  tf.math.multiply_120 (TFOp  (None, None, None, 240)      0         ['re_lu_145[0][0]']
#  Lambda)
#
#  multiply_81 (Multiply)      (None, None, None, 240)      0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_120[0][0]']
#
#  expanded_conv_5/depthwise   (None, None, None, 240)      6000      ['multiply_81[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, None, None, 240)      960       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_121 (TFOpLambd  (None, None, None, 240)      0         ['expanded_conv_5/depthwise/Ba
#  a)                                                                 tchNorm[0][0]']
#
#  re_lu_146 (ReLU)            (None, None, None, 240)      0         ['tf.math.add_121[0][0]']
#
#  tf.math.multiply_121 (TFOp  (None, None, None, 240)      0         ['re_lu_146[0][0]']
#  Lambda)
#
#  multiply_82 (Multiply)      (None, None, None, 240)      0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_121[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            0         ['multiply_82[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             15424     ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 64)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 240)            15600     ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_122 (TFOpLambd  (None, 1, 1, 240)            0         ['expanded_conv_5/squeeze_exci
#  a)                                                                 te/Conv_1[0][0]']
#
#  re_lu_147 (ReLU)            (None, 1, 1, 240)            0         ['tf.math.add_122[0][0]']
#
#  tf.math.multiply_122 (TFOp  (None, 1, 1, 240)            0         ['re_lu_147[0][0]']
#  Lambda)
#
#  expanded_conv_5/squeeze_ex  (None, None, None, 240)      0         ['multiply_82[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_122[0][0]']
#
#  expanded_conv_5/project (C  (None, None, None, 40)       9600      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, None, None, 40)       160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, None, None, 40)       0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, None, None, 120)      4800      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, None, None, 120)      480       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_123 (TFOpLambd  (None, None, None, 120)      0         ['expanded_conv_6/expand/Batch
#  a)                                                                 Norm[0][0]']
#
#  re_lu_148 (ReLU)            (None, None, None, 120)      0         ['tf.math.add_123[0][0]']
#
#  tf.math.multiply_123 (TFOp  (None, None, None, 120)      0         ['re_lu_148[0][0]']
#  Lambda)
#
#  multiply_83 (Multiply)      (None, None, None, 120)      0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_123[0][0]']
#
#  expanded_conv_6/depthwise   (None, None, None, 120)      3000      ['multiply_83[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_6/depthwise/  (None, None, None, 120)      480       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_124 (TFOpLambd  (None, None, None, 120)      0         ['expanded_conv_6/depthwise/Ba
#  a)                                                                 tchNorm[0][0]']
#
#  re_lu_149 (ReLU)            (None, None, None, 120)      0         ['tf.math.add_124[0][0]']
#
#  tf.math.multiply_124 (TFOp  (None, None, None, 120)      0         ['re_lu_149[0][0]']
#  Lambda)
#
#  multiply_84 (Multiply)      (None, None, None, 120)      0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_124[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            0         ['multiply_84[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_6/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_6/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_6/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_6/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_125 (TFOpLambd  (None, 1, 1, 120)            0         ['expanded_conv_6/squeeze_exci
#  a)                                                                 te/Conv_1[0][0]']
#
#  re_lu_150 (ReLU)            (None, 1, 1, 120)            0         ['tf.math.add_125[0][0]']
#
#  tf.math.multiply_125 (TFOp  (None, 1, 1, 120)            0         ['re_lu_150[0][0]']
#  Lambda)
#
#  expanded_conv_6/squeeze_ex  (None, None, None, 120)      0         ['multiply_84[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_125[0][0]']
#
#  expanded_conv_6/project (C  (None, None, None, 48)       5760      ['expanded_conv_6/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_6/project/Ba  (None, None, None, 48)       192       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, None, None, 144)      6912      ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, None, None, 144)      576       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.math.add_126 (TFOpLambd  (None, None, None, 144)      0         ['expanded_conv_7/expand/Batch
#  a)                                                                 Norm[0][0]']
#
#  re_lu_151 (ReLU)            (None, None, None, 144)      0         ['tf.math.add_126[0][0]']
#
#  tf.math.multiply_126 (TFOp  (None, None, None, 144)      0         ['re_lu_151[0][0]']
#  Lambda)
#
#  multiply_85 (Multiply)      (None, None, None, 144)      0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_126[0][0]']
#
#  expanded_conv_7/depthwise   (None, None, None, 144)      3600      ['multiply_85[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, None, None, 144)      576       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.math.add_127 (TFOpLambd  (None, None, None, 144)      0         ['expanded_conv_7/depthwise/Ba
#  a)                                                                 tchNorm[0][0]']
#
#  re_lu_152 (ReLU)            (None, None, None, 144)      0         ['tf.math.add_127[0][0]']
#
#  tf.math.multiply_127 (TFOp  (None, None, None, 144)      0         ['re_lu_152[0][0]']
#  Lambda)
#
#  multiply_86 (Multiply)      (None, None, None, 144)      0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_127[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            0         ['multiply_86[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             5800      ['expanded_conv_7/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 40)             0         ['expanded_conv_7/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_7/squeeze_ex  (None, 1, 1, 144)            5904      ['expanded_conv_7/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_128 (TFOpLambd  (None, 1, 1, 144)            0         ['expanded_conv_7/squeeze_exci
#  a)                                                                 te/Conv_1[0][0]']
#
#  re_lu_153 (ReLU)            (None, 1, 1, 144)            0         ['tf.math.add_128[0][0]']
#
#  tf.math.multiply_128 (TFOp  (None, 1, 1, 144)            0         ['re_lu_153[0][0]']
#  Lambda)
#
#  expanded_conv_7/squeeze_ex  (None, None, None, 144)      0         ['multiply_86[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_128[0][0]']
#
#  expanded_conv_7/project (C  (None, None, None, 48)       6912      ['expanded_conv_7/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_7/project/Ba  (None, None, None, 48)       192       ['expanded_conv_7/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/Add (Add)   (None, None, None, 48)       0         ['expanded_conv_6/project/Batc
# ...
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 576)            0         ['multiply_90[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 144)            83088     ['expanded_conv_9/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 144)            0         ['expanded_conv_9/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_9/squeeze_ex  (None, 1, 1, 576)            83520     ['expanded_conv_9/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.math.add_134 (TFOpLambd  (None, 1, 1, 576)            0         ['expanded_conv_9/squeeze_exci
#  a)                                                                 te/Conv_1[0][0]']
#
#  re_lu_159 (ReLU)            (None, 1, 1, 576)            0         ['tf.math.add_134[0][0]']
#
#  tf.math.multiply_134 (TFOp  (None, 1, 1, 576)            0         ['re_lu_159[0][0]']
#  Lambda)
#
#  expanded_conv_9/squeeze_ex  (None, None, None, 576)      0         ['multiply_90[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_134[0][0]']
#
#  expanded_conv_9/project (C  (None, None, None, 96)       55296     ['expanded_conv_9/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_9/project/Ba  (None, None, None, 96)       384       ['expanded_conv_9/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_9/Add (Add)   (None, None, None, 96)       0         ['expanded_conv_8/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_9/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_10/expand (C  (None, None, None, 576)      55296     ['expanded_conv_9/Add[0][0]']
#  onv2D)
#
#  expanded_conv_10/expand/Ba  (None, None, None, 576)      2304      ['expanded_conv_10/expand[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  tf.math.add_135 (TFOpLambd  (None, None, None, 576)      0         ['expanded_conv_10/expand/Batc
#  a)                                                                 hNorm[0][0]']
#
#  re_lu_160 (ReLU)            (None, None, None, 576)      0         ['tf.math.add_135[0][0]']
#
#  tf.math.multiply_135 (TFOp  (None, None, None, 576)      0         ['re_lu_160[0][0]']
#  Lambda)
#
#  multiply_91 (Multiply)      (None, None, None, 576)      0         ['expanded_conv_10/expand/Batc
#                                                                     hNorm[0][0]',
#                                                                      'tf.math.multiply_135[0][0]']
#
#  expanded_conv_10/depthwise  (None, None, None, 576)      14400     ['multiply_91[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_10/depthwise  (None, None, None, 576)      2304      ['expanded_conv_10/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.math.add_136 (TFOpLambd  (None, None, None, 576)      0         ['expanded_conv_10/depthwise/B
#  a)                                                                 atchNorm[0][0]']
#
#  re_lu_161 (ReLU)            (None, None, None, 576)      0         ['tf.math.add_136[0][0]']
#
#  tf.math.multiply_136 (TFOp  (None, None, None, 576)      0         ['re_lu_161[0][0]']
#  Lambda)
#
#  multiply_92 (Multiply)      (None, None, None, 576)      0         ['expanded_conv_10/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_136[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            0         ['multiply_92[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            83088     ['expanded_conv_10/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 144)            0         ['expanded_conv_10/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_10/squeeze_e  (None, 1, 1, 576)            83520     ['expanded_conv_10/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.math.add_137 (TFOpLambd  (None, 1, 1, 576)            0         ['expanded_conv_10/squeeze_exc
#  a)                                                                 ite/Conv_1[0][0]']
#
#  re_lu_162 (ReLU)            (None, 1, 1, 576)            0         ['tf.math.add_137[0][0]']
#
#  tf.math.multiply_137 (TFOp  (None, 1, 1, 576)            0         ['re_lu_162[0][0]']
#  Lambda)
#
#  expanded_conv_10/squeeze_e  (None, None, None, 576)      0         ['multiply_92[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_137[0][0]']
#
#  expanded_conv_10/project (  (None, None, None, 96)       55296     ['expanded_conv_10/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_10/project/B  (None, None, None, 96)       384       ['expanded_conv_10/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_10/Add (Add)  (None, None, None, 96)       0         ['expanded_conv_9/Add[0][0]',
#                                                                      'expanded_conv_10/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, None, None, 576)      55296     ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, None, None, 576)      2304      ['Conv_1[0][0]']
#  malization)
#
#  tf.math.add_138 (TFOpLambd  (None, None, None, 576)      0         ['Conv_1/BatchNorm[0][0]']
#  a)
#
#  re_lu_163 (ReLU)            (None, None, None, 576)      0         ['tf.math.add_138[0][0]']
#
#  tf.math.multiply_138 (TFOp  (None, None, None, 576)      0         ['re_lu_163[0][0]']
#  Lambda)
#
#  multiply_93 (Multiply)      (None, None, None, 576)      0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_138[0][0]']
#
#  global_average_pooling2d_4  (None, 1, 1, 576)            0         ['multiply_93[0][0]']
#   (GlobalAveragePooling2D)
#
#  Conv_2 (Conv2D)             (None, 1, 1, 1024)           590848    ['global_average_pooling2d_4[0
#                                                                     ][0]']
#
#  tf.math.add_139 (TFOpLambd  (None, 1, 1, 1024)           0         ['Conv_2[0][0]']
#  a)
#
#  re_lu_164 (ReLU)            (None, 1, 1, 1024)           0         ['tf.math.add_139[0][0]']
#
#  tf.math.multiply_139 (TFOp  (None, 1, 1, 1024)           0         ['re_lu_164[0][0]']
#  Lambda)
#
#  multiply_94 (Multiply)      (None, 1, 1, 1024)           0         ['Conv_2[0][0]',
#                                                                      'tf.math.multiply_139[0][0]']
#
#  dropout_4 (Dropout)         (None, 1, 1, 1024)           0         ['multiply_94[0][0]']
#
#  Logits (Conv2D)             (None, 1, 1, 1000)           1025000   ['dropout_4[0][0]']
#
#  flatten_4 (Flatten)         (None, 1000)                 0         ['Logits[0][0]']
#
#  Predictions (Activation)    (None, 1000)                 0         ['flatten_4[0][0]']
#
#  dense_4 (Dense)             (None, 64)                   64064     ['Predictions[0][0]']
#
#  dense_5 (Dense)             (None, 30)                   1950      ['dense_4[0][0]']
#
#  dense_6 (Dense)             (None, 30)                   930       ['dense_5[0][0]']
#
#  dense_7 (Dense)             (None, 7)                    217       ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 2622129 (10.00 MB)
# Trainable params: 67161 (262.35 KB)
# Non-trainable params: 2554968 (9.75 MB)
# __________________________________________________________________________________________________

# %%
# loss and optimizer
loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
optim = keras.optimizers.Adam(learning_rate=0.001)
metrics = ["accuracy"]

new_model.compile(optimizer=optim, loss=loss, metrics=metrics)

# %%
epochs = 30

early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True,
    verbose=2,
    start_from_epoch=0
)
#tf.keras.callbacks.EarlyStopping(
#    monitor='val_loss',
#    min_delta=0,
#    patience=0,
#    verbose=0,
#    mode='auto',
#    baseline=None,
#    restore_best_weights=False,

new_model.fit(train_batches, validation_data=val_batches,
            callbacks=[early_stopping],
          epochs=epochs, verbose=1)
# Out:
# Epoch 1/30
#  77/525 [===>..........................] - ETA: 12s - loss: 1.9315 - accuracy: 0.2727
# C:\Users\Amirul\AppData\Local\Programs\Python\Python311\Lib\site-packages\PIL\Image.py:996: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 525/525 [==============================] - 23s 39ms/step - loss: 1.3195 - accuracy: 0.5529 - val_loss: 0.7054 - val_accuracy: 0.7760
# Epoch 2/30
# 525/525 [==============================] - 20s 38ms/step - loss: 0.7000 - accuracy: 0.7614 - val_loss: 0.6108 - val_accuracy: 0.7794
# Epoch 3/30
# 525/525 [==============================] - 20s 38ms/step - loss: 0.5857 - accuracy: 0.7986 - val_loss: 0.5753 - val_accuracy: 0.8160
# Epoch 4/30
# 525/525 [==============================] - 28s 53ms/step - loss: 0.5061 - accuracy: 0.8214 - val_loss: 0.5492 - val_accuracy: 0.8023
# Epoch 5/30
# 525/525 [==============================] - 23s 43ms/step - loss: 0.4328 - accuracy: 0.8495 - val_loss: 0.5578 - val_accuracy: 0.8297
# Epoch 6/30
# 525/525 [==============================] - 22s 42ms/step - loss: 0.3955 - accuracy: 0.8571 - val_loss: 0.5604 - val_accuracy: 0.8514
# Epoch 7/30
# 525/525 [==============================] - 21s 39ms/step - loss: 0.3997 - accuracy: 0.8590 - val_loss: 0.5429 - val_accuracy: 0.8514
# Epoch 8/30
# 525/525 [==============================] - 21s 39ms/step - loss: 0.3583 - accuracy: 0.8771 - val_loss: 0.5125 - val_accuracy: 0.8480
# Epoch 9/30
# 525/525 [==============================] - 20s 38ms/step - loss: 0.3265 - accuracy: 0.8800 - val_loss: 0.5790 - val_accuracy: 0.8229
# Epoch 10/30
# 525/525 [==============================] - 20s 38ms/step - loss: 0.3013 - accuracy: 0.8971 - val_loss: 0.6006 - val_accuracy: 0.8297
# Epoch 11/30
# 525/525 [==============================] - 20s 38ms/step - loss: 0.2830 - accuracy: 0.8981 - val_loss: 0.5991 - val_accuracy: 0.8400
# Epoch 12/30
# 525/525 [==============================] - 20s 39ms/step - loss: 0.2725 - accuracy: 0.9052 - val_loss: 0.5974 - val_accuracy: 0.8251
# Epoch 13/30
# 524/525 [============================>.] - ETA: 0s - loss: 0.2629 - accuracy: 0.9041Restoring model weights from the end of the best epoch: 8.
# 525/525 [==============================] - 20s 38ms/step - loss: 0.2626 - accuracy: 0.9043 - val_loss: 0.5954 - val_accuracy: 0.8331
# Epoch 13: early stopping

# %%
new_model.evaluate(test_batches, verbose=1)
# Out:
# 525/525 [==============================] - 6s 11ms/step - loss: 0.5495 - accuracy: 0.8419
# [0.5494892597198486, 0.8419047594070435]

# %%
new_model.save("MobileNetV3_64relu_30relu_30relu_7L_BD500.keras") #saving trained model

# %%
loadmodel=tf.keras.models.load_model("MobileNetV3_64relu_30relu_30relu_7L_BD500.keras")

# %%
# make some predictions
predictions = loadmodel.predict(test_batches)
predictions = tf.nn.softmax(predictions)
labels = np.argmax(predictions, axis=1)
# Out:
# 525/525 [==============================] - 6s 10ms/step

# %%
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
from sklearn.metrics import classification_report
import seaborn as sns

Classes = ["Cardboard boxes","Cardboard drinks","glass","Metal cans","Metal foils and container","paper","Plastic bottles"]


def plot2(y_actual,y_true):

    column=[f'Predicted {label}'for label in Classes]
    indices=[f'Actual {label}' for label in Classes]
    table=pd.DataFrame(confusion_matrix(y_actual,y_result),
                       columns=column,index=indices)

    
    return sns.heatmap(table,annot=True,fmt='d',cmap='Blues') 
    
y_actual=test_batches.labels
y_result=labels

# %%
plot2(y_actual,y_result)
# Out:
# <Axes: >

# %%
#Confusion matrix report

matrix=classification_report(y_actual,y_result)
print('Classification report: \n',matrix)
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.91      0.84        75
#            1       0.86      1.00      0.93        75
#            2       0.77      0.87      0.82        75
#            3       0.94      0.64      0.76        75
#            4       0.93      0.99      0.95        75
#            5       0.90      0.76      0.83        75
#            6       0.75      0.73      0.74        75
#
#     accuracy                           0.84       525
#    macro avg       0.85      0.84      0.84       525
# weighted avg       0.85      0.84      0.84       525

# %%
modelname='MobileNetV3_64relu_30relu_30relu_7L_BD500_summary.txt'
def myprint(s):
    with open(modelname,'a') as f:
        print(s, file=f)

loadmodel.summary(print_fn=myprint)

file2write=open(modelname,'a')
file2write.write(matrix)
file2write.close()

# %%
from sklearn.metrics import confusion_matrix
import numpy as np

conf_matrix = confusion_matrix(y_actual,y_result)

# Labeling the rows and columns
classes = ["0","1","2","3","4","5","6"]
conf_matrix_labeled = np.vstack((np.array([""] + classes), np.column_stack((np.array(classes), conf_matrix))))

# Convert the confusion matrix to a formatted string
conf_matrix_text = "Confusion Matrix:\n" + str(conf_matrix)

# Specify the path of the summary text file
summary_file_path = modelname

# Read the content of the summary file
with open(summary_file_path, 'r') as summary_file:
    summary_content = summary_file.read()
additional_text = "\nClasses :\n Cardboard boxes=0\n Cardboard drinks=1\n glass=2\n Metal cans=3\n Metal foils and container=4\n paper=5\n Plastic bottles=6"
# Append the confusion matrix content to the summary content
combined_content = summary_content + '\n\n' + conf_matrix_text + '\n\n'+additional_text

# Write the combined content back to the summary file
with open(summary_file_path, 'w') as summary_file:
    summary_file.write(combined_content)

print(f"Confusion matrix added to {summary_file_path}")
# Out:
# Confusion matrix added to MobileNetV3_64relu_30relu_30relu_7L_BD500_summary.txt
